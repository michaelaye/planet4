# %%
from planet4.clustering import DBScanner

# %%
dbname = '/Users/klay6683/data/planet4/2015-06-07_planet_four_classifications_queryable_cleaned_seasons2and3.h5'

# %%
from planet4 import markings, p4io

class ClusteringManager(object):
    def __init__(self, dbname, scope='hirise'):
        self.db = p4io.DBManager(dbname)
        self.dbname = dbname
        self.scope = scope
        self.confusion = []
        self.dbscanners = []
        self.clustered_fans = []
        self.clustered_blotches = []
        
    @property
    def n_clustered_fans(self):
        return len(self.clustered_fans)
    
    @property
    def n_clustered_blotches(self):
        return len(self.clustered_blotches)
    
    def dbscan_data(self, data):
        for kind in ['fan','blotch']:
            markings = data[data.marking==kind]
            dbscanner = DBScanner(markings, 
                                  kind, 
                                  scope=self.scope)
            self.confusion.append((self.data_id,
                                   kind,
                                   len(markings),
                                   dbscanner.n_reduced_data,
                                   dbscanner.n_rejected))
            if kind == 'fan':
                self.clustered_fans.extend(dbscanner.reduced_data)
            else:
                self.clustered_blotches.extend(dbscanner.reduced_data)

    def dbscan_image_id(self, image_id):
        self.data_id = image_id
        self.p4id = markings.ImageID(image_id, self.dbname)
        self.dbscan_data(self.p4id.data)
        
    def dbscan_image_name(self, image_name):
        data = self.db.get_image_name_markings(image_name)
        self.data_id = image_name
        self.dbscan_data(data)
        
    def dbscan_all(self):
        image_names = self.db.image_names
        for i, image_name in enumerate(image_names):
            print('{:.1f}'.format(100*i/len(image_names)))
            data = self.db.get_image_name_markings(image_name)
            self.data_id = image_name
            self.dbscan_data(data)

# %%
cm = ClusteringManager(dbname)

# %%
cm.dbscan_image_name('ESP_011544_0985')

# %%
from numpy.linalg import norm

n_close = 0
for blotch in cm.clustered_blotches:
    for fan in cm.clustered_fans:
        delta = blotch.center - (fan.base+fan.midpoint)
        if norm(delta) < 10 :
           n_close += 1

# %%
n_close
# Out:
# 75

# %%
cm.n_clustered_blotches
# Out:
# 645

# %%
cm.n_clustered_fans
# Out:
# 181

# %%
cm.db.get_image_id_markings('APF00002q1')
# Out:
#             classification_id          created_at    image_id  \
# 0    50ec004b3fc11706e7000c3c 2013-01-08 11:17:31  APF00002q1
# 1    50ef1da084af3b013b000001 2013-01-10 19:57:16  APF00002q1
# 2    50f03a929b15ae77d0000001 2013-01-11 16:15:14  APF00002q1
# 3    50ee8f8d84af3b175c000001 2013-01-10 09:53:18  APF00002q1
# 4    50ef6d8795e6e42152000001 2013-01-10 22:53:53  APF00002q1
# 5    50ecbbe360d40512d100000d 2013-01-09 00:37:55  APF00002q1
# 6    50eda7455aadce750b0000d1 2013-01-09 17:22:13  APF00002q1
# 7    50ef613e95e6e4471c000001 2013-01-10 22:25:22  APF00002q1
# 8    50ef0ba684af3b6686000001 2013-01-10 18:42:13  APF00002q1
# 9    50ee5a5884af3b673b000001 2013-01-09 22:34:24  APF00002q1
# 10   50ed5d4960d4053e83001362 2013-01-09 12:06:33  APF00002q1
# 11   50ed5d4960d4053e83001362 2013-01-09 12:06:33  APF00002q1
# 12   50ed5d4960d4053e83001362 2013-01-09 12:06:33  APF00002q1
# 13   50eff21c95e6e45db5000001 2013-01-11 10:59:45  APF00002q1
# 14   50ee1298e792ed6fdf000277 2013-01-10 01:00:08  APF00002q1
# 15   50ecc5d160d40527530001af 2013-01-09 01:20:17  APF00002q1
# 16   50ecb3c65aadce2790000135 2013-01-09 00:03:18  APF00002q1
# 17   50ecb3c65aadce2790000135 2013-01-09 00:03:18  APF00002q1
# 18   50ecb3c65aadce2790000135 2013-01-09 00:03:18  APF00002q1
# 19   50edb9da60d4050d3d0002dd 2013-01-09 18:41:30  APF00002q1
# 20   50edb9da60d4050d3d0002dd 2013-01-09 18:41:30  APF00002q1
# 21   50ecba989ba28b0fd1000099 2013-01-09 00:32:24  APF00002q1
# 22   50ec9494e99e95082500000b 2013-01-08 21:50:12  APF00002q1
# 23   50ecb91b5aadce5ed2000164 2013-01-09 00:26:03  APF00002q1
# 24   50ec99fb5dff9509ba000056 2013-01-08 22:13:15  APF00002q1
# 25   50ec99fb5dff9509ba000056 2013-01-08 22:13:15  APF00002q1
# 26   50ec99fb5dff9509ba000056 2013-01-08 22:13:15  APF00002q1
# 27   50ec99fb5dff9509ba000056 2013-01-08 22:13:15  APF00002q1
# 28   50ee6d1b84af3b733d000001 2013-01-09 23:48:57  APF00002q1
# 29   50eecb9be792ed1550000001 2013-01-10 14:09:31  APF00002q1
# ..                        ...                 ...         ...
# 122  50ef76a695e6e40563000001 2013-01-10 23:24:42  APF00002q1
# 123  50eea8e584af3b2976000001 2013-01-10 11:41:26  APF00002q1
# 124  50edd6e046afd607e5000197 2013-01-09 20:45:20  APF00002q1
# 125  50ef834595e6e433b6000001 2013-01-11 01:10:22  APF00002q1
# 126  50ee55e084af3b6c92000001 2013-01-09 22:21:55  APF00002q1
# 127  50ec9b345dff95074400001f 2013-01-08 22:18:28  APF00002q1
# 128  50ef7fac95e6e45f8a000001 2013-01-11 00:17:15  APF00002q1
# 129  50ef4c4995e6e441ab000001 2013-01-10 21:51:09  APF00002q1
# 130  50ef4c4995e6e441ab000001 2013-01-10 21:51:09  APF00002q1
# 131  50ef4c4995e6e441ab000001 2013-01-10 21:51:09  APF00002q1
# 132  50ef4c4995e6e441ab000001 2013-01-10 21:51:09  APF00002q1
# 133  50ef6a3b95e6e46691000001 2013-01-10 22:45:07  APF00002q1
# 134  50ef1d3a84af3b5a81000001 2013-01-10 19:55:01  APF00002q1
# 135  50edd449b2bf9c09ef000039 2013-01-09 20:34:17  APF00002q1
# 136  50edd449b2bf9c09ef000039 2013-01-09 20:34:17  APF00002q1
# 137  50ee44e184af3b7838000001 2013-01-09 21:45:50  APF00002q1
# 138  50ec9d0b9ba28b0d5000010c 2013-01-08 22:26:19  APF00002q1
# 139  50eda50e60d4051d12000031 2013-01-09 17:12:46  APF00002q1
# 140  50ee64c984af3b43bc000001 2013-01-09 23:04:10  APF00002q1
# 141  50ed99909ba28b0c800000c6 2013-01-09 16:23:44  APF00002q1
# 142  50ef747395e6e4353a000001 2013-01-10 23:17:15  APF00002q1
# 143  50ef0e9884af3b676a000001 2013-01-10 18:52:23  APF00002q1
# 144  50edd786d897dc088800014a 2013-01-09 20:48:06  APF00002q1
# 145  50ef991395e6e43d29000001 2013-01-11 04:44:08  APF00002q1
# 146  50ef3ec195e6e40357000001 2013-01-10 21:20:16  APF00002q1
# 147  50ee5b1284af3b262e000001 2013-01-09 22:36:43  APF00002q1
# 148  50ed9fb760d4056c210001a3 2013-01-09 16:49:59  APF00002q1
# 149  50ee4c4c94b9d55a27000001 2013-01-09 22:00:55  APF00002q1
# 150  50ec88e9e04c0e1c1c00000a 2013-01-08 21:00:25  APF00002q1
# 151  50ef7fe395e6e47470000001 2013-01-11 00:23:40  APF00002q1
#
#           image_name                                          image_url  \
# 0    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 1    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 2    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 3    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 4    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 5    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 6    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 7    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 8    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 9    ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 10   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 11   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 12   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 13   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 14   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 15   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 16   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 17   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 18   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 19   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 20   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 21   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 22   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 23   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 24   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 25   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 26   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 27   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 28   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 29   ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# ..               ...                                                ...
# 122  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 123  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 124  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 125  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 126  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 127  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 128  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 129  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 130  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 131  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 132  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 133  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 134  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 135  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 136  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 137  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 138  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 139  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 140  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 141  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 142  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 143  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 144  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 145  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 146  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 147  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 148  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 149  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 150  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
# 151  ESP_011544_0985  http://www.planetfour.org/subjects/standard/50...
#
#                                           user_name      marking  x_tile  \
# 0                                           Allie42       blotch       1
# 1                                         BODYonICE       blotch       1
# 2                                           CWOWALL         none       1
# 3                                          ChesterG         none       1
# 4                                         ChrisHigs         none       1
# 5                                   CollapsedOrange         none       1
# 6                                        DLB1989Tol         none       1
# 7                                     Daniel_Wilson         none       1
# 8                                  Davescunningplan         none       1
# 9                                        Eric_Hulme         none       1
# 10                                           Euphon       blotch       1
# 11                                           Euphon       blotch       1
# 12                                           Euphon          fan       1
# 13                                       FuzzyDweeb         none       1
# 14                                       Hollie2010         none       1
# 15                                       JDspaceman         none       1
# 16                                     JohnChesebro       blotch       1
# 17                                     JohnChesebro  interesting       1
# 18                                     JohnChesebro  interesting       1
# 19                                      Kolbeinsvik       blotch       1
# 20                                      Kolbeinsvik          fan       1
# 21                                          LoupDee         none       1
# 22                                  MasonThreeSixty         none       1
# 23                                         Mgayette         none       1
# 24                                    Mike A Taylor       blotch       1
# 25                                    Mike A Taylor  interesting       1
# 26                                    Mike A Taylor  interesting       1
# 27                                    Mike A Taylor  interesting       1
# 28                                          MrKunle         none       1
# 29                              PaulCookPhotography         none       1
# ..                                              ...          ...     ...
# 122  not-logged-in-cdc45c39bf3e445e0d5d57723274f211         none       1
# 123  not-logged-in-d088ce332efac7bf6aa4c392e4be0270         none       1
# 124  not-logged-in-d61aa5acbdf8e8b7d4aeca611d60cfa8  interesting       1
# 125  not-logged-in-da89870e50f6cfc01cae8e5a0e76abd3         none       1
# 126  not-logged-in-e3d28d24b28df024831c461c2054ad05         none       1
# 127  not-logged-in-f6515a8490472ae163880048eb3840c6         none       1
# 128  not-logged-in-f74b5d09dfff43b4f5b024daf190c72b         none       1
# 129                                         ntch101  interesting       1
# 130                                         ntch101  interesting       1
# 131                                         ntch101  interesting       1
# 132                                         ntch101  interesting       1
# 133                                         number1         none       1
# 134                                       oulty1207         none       1
# 135                                  partridgedavid       blotch       1
# 136                                  partridgedavid       blotch       1
# 137                                         pdman39         none       1
# 138                                    peter hedges         none       1
# 139                                        philiano         none       1
# 140                                      salander78         none       1
# 141                                   semisilentbob         none       1
# 142                                         shamlin         none       1
# 143                                      shauny0708         none       1
# 144                                     sigmaslash5         none       1
# 145                                 silverstargazer         none       1
# 146                                       spike1973         none       1
# 147                                     tanders1962         none       1
# 148                                      totheshore         none       1
# 149                                        turboelf         none       1
# 150                                        turnermr         none       1
# 151                                        viperjon         none       1
#
#      y_tile acquisition_date    ...        image_x       image_y   radius_1  \
# 0        63       2009-01-12    ...      91.500000  34061.000000  10.000000
# 1        63       2009-01-12    ...      86.000000  34055.000000  10.000000
# 2        63       2009-01-12    ...            NaN           NaN        NaN
# 3        63       2009-01-12    ...            NaN           NaN        NaN
# 4        63       2009-01-12    ...            NaN           NaN        NaN
# 5        63       2009-01-12    ...            NaN           NaN        NaN
# 6        63       2009-01-12    ...            NaN           NaN        NaN
# 7        63       2009-01-12    ...            NaN           NaN        NaN
# 8        63       2009-01-12    ...            NaN           NaN        NaN
# 9        63       2009-01-12    ...            NaN           NaN        NaN
# 10       63       2009-01-12    ...      90.000000  34059.000000  12.529964
# 11       63       2009-01-12    ...     445.000000  34317.000000  46.010868
# 12       63       2009-01-12    ...      75.000000  34377.000000        NaN
# 13       63       2009-01-12    ...            NaN           NaN        NaN
# 14       63       2009-01-12    ...            NaN           NaN        NaN
# 15       63       2009-01-12    ...            NaN           NaN        NaN
# 16       63       2009-01-12    ...     443.500000  34320.000000  40.000000
# 17       63       2009-01-12    ...     782.500000  34559.000000        NaN
# 18       63       2009-01-12    ...     112.500000  34298.000000        NaN
# 19       63       2009-01-12    ...     445.500000  34318.000000  25.079872
# 20       63       2009-01-12    ...      91.500000  34356.000000        NaN
# 21       63       2009-01-12    ...            NaN           NaN        NaN
# 22       63       2009-01-12    ...            NaN           NaN        NaN
# 23       63       2009-01-12    ...            NaN           NaN        NaN
# 24       63       2009-01-12    ...     441.000000  34317.000000  33.241540
# 25       63       2009-01-12    ...     775.000000  34163.000000        NaN
# 26       63       2009-01-12    ...     796.000000  34572.000000        NaN
# 27       63       2009-01-12    ...     110.000000  34305.000000        NaN
# 28       63       2009-01-12    ...            NaN           NaN        NaN
# 29       63       2009-01-12    ...            NaN           NaN        NaN
# ..      ...              ...    ...            ...           ...        ...
# 122      63       2009-01-12    ...            NaN           NaN        NaN
# 123      63       2009-01-12    ...            NaN           NaN        NaN
# 124      63       2009-01-12    ...      81.000000  34340.000000        NaN
# 125      63       2009-01-12    ...            NaN           NaN        NaN
# 126      63       2009-01-12    ...            NaN           NaN        NaN
# 127      63       2009-01-12    ...            NaN           NaN        NaN
# 128      63       2009-01-12    ...            NaN           NaN        NaN
# 129      63       2009-01-12    ...     800.500000  34569.000000        NaN
# 130      63       2009-01-12    ...      27.500000  34456.000000        NaN
# 131      63       2009-01-12    ...      80.500000  34343.000000        NaN
# 132      63       2009-01-12    ...     442.500000  34315.000000        NaN
# 133      63       2009-01-12    ...            NaN           NaN        NaN
# 134      63       2009-01-12    ...            NaN           NaN        NaN
# 135      63       2009-01-12    ...      85.923065  34088.307691  10.000000
# 136      63       2009-01-12    ...      87.461517  34056.769231  20.000008
# 137      63       2009-01-12    ...            NaN           NaN        NaN
# 138      63       2009-01-12    ...            NaN           NaN        NaN
# 139      63       2009-01-12    ...            NaN           NaN        NaN
# 140      63       2009-01-12    ...            NaN           NaN        NaN
# 141      63       2009-01-12    ...            NaN           NaN        NaN
# 142      63       2009-01-12    ...            NaN           NaN        NaN
# 143      63       2009-01-12    ...            NaN           NaN        NaN
# 144      63       2009-01-12    ...            NaN           NaN        NaN
# 145      63       2009-01-12    ...            NaN           NaN        NaN
# 146      63       2009-01-12    ...            NaN           NaN        NaN
# 147      63       2009-01-12    ...            NaN           NaN        NaN
# 148      63       2009-01-12    ...            NaN           NaN        NaN
# 149      63       2009-01-12    ...            NaN           NaN        NaN
# 150      63       2009-01-12    ...            NaN           NaN        NaN
# 151      63       2009-01-12    ...            NaN           NaN        NaN
#
#       radius_2    distance       angle      spread  version  hirise_x  \
# 0    10.000000         NaN    0.000000    0.000000        1        92
# 1    10.000000         NaN    0.000000    0.000000        1        86
# 2          NaN         NaN         NaN    0.000000        1       NaN
# 3          NaN         NaN         NaN    0.000000        1       NaN
# 4          NaN         NaN         NaN    0.000000        1       NaN
# 5          NaN         NaN         NaN    0.000000        1       NaN
# 6          NaN         NaN         NaN    0.000000        1       NaN
# 7          NaN         NaN         NaN    0.000000        1       NaN
# 8          NaN         NaN         NaN    0.000000        1       NaN
# 9          NaN         NaN         NaN    0.000000        1       NaN
# 10   10.000000         NaN   28.610460    0.000000        1        90
# 11   34.508151         NaN   -1.245364    0.000000        1       445
# 12         NaN  184.837767  -61.216367  129.729320        1        75
# 13         NaN         NaN         NaN    0.000000        1       NaN
# 14         NaN         NaN         NaN    0.000000        1       NaN
# 15         NaN         NaN         NaN    0.000000        1       NaN
# 16   26.476405         NaN    0.000000    0.000000        1       444
# 17         NaN         NaN         NaN    0.000000        1       782
# 18         NaN         NaN         NaN    0.000000        1       112
# 19   18.809904         NaN -156.501434    0.000000        1       446
# 20         NaN  158.647408  -59.717567   26.969764        1        92
# 21         NaN         NaN         NaN    0.000000        1       NaN
# 22         NaN         NaN         NaN    0.000000        1       NaN
# 23         NaN         NaN         NaN    0.000000        1       NaN
# 24   31.384710         NaN   59.349332    0.000000        1       441
# 25         NaN         NaN         NaN    0.000000        1       775
# 26         NaN         NaN         NaN    0.000000        1       796
# 27         NaN         NaN         NaN    0.000000        1       110
# 28         NaN         NaN         NaN    0.000000        1       NaN
# 29         NaN         NaN         NaN    0.000000        1       NaN
# ..         ...         ...         ...         ...      ...       ...
# 122        NaN         NaN         NaN    0.000000        1       NaN
# 123        NaN         NaN         NaN    0.000000        1       NaN
# 124        NaN         NaN         NaN    0.000000        1        81
# 125        NaN         NaN         NaN    0.000000        1       NaN
# 126        NaN         NaN         NaN    0.000000        1       NaN
# 127        NaN         NaN         NaN    0.000000        1       NaN
# 128        NaN         NaN         NaN    0.000000        1       NaN
# 129        NaN         NaN         NaN    0.000000        1       800
# 130        NaN         NaN         NaN    0.000000        1        28
# 131        NaN         NaN         NaN    0.000000        1        80
# 132        NaN         NaN         NaN    0.000000        1       442
# 133        NaN         NaN         NaN    0.000000        1       NaN
# 134        NaN         NaN         NaN    0.000000        1       NaN
# 135  10.000000         NaN    0.000000    0.000000        1        86
# 136  10.000000         NaN   22.619851    0.000000        1        87
# 137        NaN         NaN         NaN    0.000000        1       NaN
# 138        NaN         NaN         NaN    0.000000        1       NaN
# 139        NaN         NaN         NaN    0.000000        1       NaN
# 140        NaN         NaN         NaN    0.000000        1       NaN
# 141        NaN         NaN         NaN    0.000000        1       NaN
# 142        NaN         NaN         NaN    0.000000        1       NaN
# 143        NaN         NaN         NaN    0.000000        1       NaN
# 144        NaN         NaN         NaN    0.000000        1       NaN
# 145        NaN         NaN         NaN    0.000000        1       NaN
# 146        NaN         NaN         NaN    0.000000        1       NaN
# 147        NaN         NaN         NaN    0.000000        1       NaN
# 148        NaN         NaN         NaN    0.000000        1       NaN
# 149        NaN         NaN         NaN    0.000000        1       NaN
# 150        NaN         NaN         NaN    0.000000        1       NaN
# 151        NaN         NaN         NaN    0.000000        1       NaN
#
#      hirise_y
# 0       34061
# 1       34055
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10      34059
# 11      34317
# 12      34377
# 13        NaN
# 14        NaN
# 15        NaN
# 16      34320
# 17      34559
# 18      34298
# 19      34318
# 20      34356
# 21        NaN
# 22        NaN
# 23        NaN
# 24      34317
# 25      34163
# 26      34572
# 27      34305
# 28        NaN
# 29        NaN
# ..        ...
# 122       NaN
# 123       NaN
# 124     34340
# 125       NaN
# 126       NaN
# 127       NaN
# 128       NaN
# 129     34569
# 130     34456
# 131     34343
# 132     34315
# 133       NaN
# 134       NaN
# 135     34088
# 136     34057
# 137       NaN
# 138       NaN
# 139       NaN
# 140       NaN
# 141       NaN
# 142       NaN
# 143       NaN
# 144       NaN
# 145       NaN
# 146       NaN
# 147       NaN
# 148       NaN
# 149       NaN
# 150       NaN
# 151       NaN
#
# [152 rows x 23 columns]

# %%
n_close
# Out:
# 0

# %%
confusion_data = pd.DataFrame(cm.confusion, columns=['image_name', 'kind', 'n_markings',
                                    'n_cluster_members', 'n_rejected'])

# %%
confusion_data.to_csv('/Users/klay6683/Dropbox/DDocuments/planet4/confusion_data.csv')

# %%
from numpy.linalg import norm

for blotch in reduced_blotches:
    print(blotch.center)
    for fan in reduced_fans:
        delta = blotch.center - (fan.base+fan.midpoint)
        print(norm(delta))
