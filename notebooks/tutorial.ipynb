# %%
from planet4 import get_data, markings
reload(markings)
# Out:
# <module 'planet4.markings' from '/Users/maye/Dropbox/src/P4_sandbox/planet4/markings.py'>

# %%
tuts = get_data.get_latest_tutorial_data()

# %%
tuts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406616 entries, 1102149 to 11843807
# Data columns (total 20 columns):
# classification_id    406616 non-null object
# created_at           406616 non-null datetime64[ns]
# image_id             406616 non-null object
# image_name           406616 non-null object
# image_url            406616 non-null object
# user_name            406616 non-null object
# marking              406616 non-null object
# x_tile               406616 non-null int64
# y_tile               406616 non-null int64
# acquisition_date     406616 non-null datetime64[ns]
# local_mars_time      0 non-null object
# x                    373252 non-null float64
# y                    373252 non-null float64
# image_x              373252 non-null float64
# image_y              373252 non-null float64
# radius_1             139038 non-null float64
# radius_2             139038 non-null float64
# distance             223003 non-null float64
# angle                362041 non-null float64
# spread               223001 non-null float64
# dtypes: datetime64[ns](2), float64(9), int64(2), object(7)

# %%
users = tuts.user_name.unique()

# %%
import logging

# %%
log = logging.getLogger()

# %%
log.setLevel(logging.INFO)

# %%
user = users[randint(0,len(users))]
userdata = tuts[tuts.user_name==user]
idobj = markings.P4_ImgID(userdata.image_id.iloc[0], data=userdata)
idobj.plot_fans()
