# %% [markdown]
# # Table of Contents
#  <p>

# %%
from planet4.markings import ImageID

# %%
p4id = ImageID('1wg')

# %%
# %matplotlib nbagg

# %%
p4id.show_subframe()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
path = '/Users/klay6683/Dropbox/p4_4Chase/inca/inca_fans.csv'

# %%
inca = pd.read_csv(path)

# %%
p4id.plot_fans(data=inca[inca.image_id=='APF00001wg'])
# Out:
# <img src="data:image/png;base64,..." width="800">
